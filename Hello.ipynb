# %%
import pandas

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed
# bogomips	: 4399.99
# ...

# %%
quit  `!cat /proc/meminfo
# Out:
# MemTotal:       13297200 kB
# MemFree:         9309024 kB
# MemAvailable:   12395212 kB
# Buffers:          340092 kB
# Cached:          2903000 kB
# SwapCached:            0 kB
# Active:           610384 kB
# Inactive:        3151296 kB
# Active(anon):        964 kB
# Inactive(anon):   497032 kB
# Active(file):     609420 kB
# Inactive(file):  2654264 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               560 kB
# Writeback:            44 kB
# AnonPages:        518596 kB
# Mapped:           258728 kB
# Shmem:              1296 kB
# KReclaimable:     127912 kB
# Slab:             157860 kB
# SReclaimable:     127912 kB
# SUnreclaim:        29948 kB
# KernelStack:        4048 kB
# PageTables:         9956 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6648600 kB
# Committed_AS:    2429108 kB
# VmallocTotal:   34359738367 kB
# ...

# %%
# !cat /proc/gpuinfo
# Out:
# cat: /proc/gpuinfo: No such file or directory
